# %%
import pandas as pd
df = pd.read_csv('emp.csv')
df
# Out:
#     eno    ename  salary  deptno         doj
# 0    10    Amber    1000      10  2018-05-14
# 1     2     Amar    1000      10  2017-03-22
# 2     8    Sagar    1000      20  2020-11-30
# 3     4   Thomas    1000      10  2019-08-18
# 4     5     Jade    2000      10  2021-02-10
# 5     6    Smith    1000      10  2016-12-01
# 6     7   Robert    3000      20  2023-06-25
# 7     3     Nick    1000      30  2015-09-15
# 8     9    Naman    4000      30  2020-01-20
# 9     1    Vikas    1000      30  2017-10-03
# 10   11   Dennis   41000      30  2024-01-05
# 11   12    Karan    2200      20  2018-06-16
# 12   13   Simran    1500      10  2019-12-19
# 13   14     Amit    2000      30  2022-04-09
# 14   15     Neha    1700      20  2021-07-22
# 15   16    Rahul    1200      10  2016-03-28
# 16   17    Divya    3000      30  2015-11-11
# 17   18   Rakesh    1800      10  2020-09-04
# 18   19   Monica    2500      20  2023-08-07
# 19   20     John    2300      30  2018-10-29
# ...

# %%
import pandas as pd

df = pd.read_excel("employees.xlsx", engine="openpyxl")

df
# Out:
#    Employee_ID    Name Department  Salary Joining_Date
# 0          101    Amit         HR   50000   2022-01-10
# 1          102  Bhavna    Finance   60000   2021-03-15
# 2          103  Chetan         IT   55000   2020-07-01
# 3          104   Divya  Marketing   52000   2023-02-20

# %%
df
# Out:
#    Employee_ID    Name Department  Salary Joining_Date
# 0          101    Amit         HR   50000   2022-01-10
# 1          102  Bhavna    Finance   60000   2021-03-15
# 2          103  Chetan         IT   55000   2020-07-01
# 3          104   Divya  Marketing   52000   2023-02-20

# %%
data = {
"Employee_ID": [101, 102, 103, 104],
"Name": ["Amit", "Bhavna", "Chetan", "Divya"],
"Department": ["HR", "Finance", "IT", "Marketing"],
"Salary": [50000, 60000, 55000, 52000],
"Joining_Date": ["2022-01-10", "2021-03-15", "2020-07-01", "2023-02-20"]
}
df = pd.DataFrame(data)
df
# Out:
#    Employee_ID    Name Department  Salary Joining_Date
# 0          101    Amit         HR   50000   2022-01-10
# 1          102  Bhavna    Finance   60000   2021-03-15
# 2          103  Chetan         IT   55000   2020-07-01
# 3          104   Divya  Marketing   52000   2023-02-20

# %%
df_write_excel =df.to_excel('employees.xlsx', index=False, sheet_name='EmployeeData')
df_write_excel

# %%
df_write_excel

# %%
df_excel = pd.read_excel('employees.xlsx', sheet_name='EmployeeData')
df_excel
# Out:
#    Employee_ID    Name Department  Salary Joining_Date
# 0          101    Amit         HR   50000   2022-01-10
# 1          102  Bhavna    Finance   60000   2021-03-15
# 2          103  Chetan         IT   55000   2020-07-01
# 3          104   Divya  Marketing   52000   2023-02-20

# %%
df.to_json("employees.json",index=False,orient='records',indent=3)

# %%
df_read_json = pd.read_json('employees.json')

# %%
df_read_json
# Out:
#    Employee_ID    Name Department  Salary Joining_Date
# 0          101    Amit         HR   50000   2022-01-10
# 1          102  Bhavna    Finance   60000   2021-03-15
# 2          103  Chetan         IT   55000   2020-07-01
# 3          104   Divya  Marketing   52000   2023-02-20

# %%
df.to_parquet("employees.parquet",engine="pyarrow")

# %%
# %pip install pyarrow
# Out:
# ...
#   Using cached pyarrow-21.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Using cached pyarrow-21.0.0-cp313-cp313-win_amd64.whl (26.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df
# Out:
#     eno    ename  salary  deptno         doj
# 0    10    Amber    1000      10  2018-05-14
# 1     2     Amar    1000      10  2017-03-22
# 2     8    Sagar    1000      20  2020-11-30
# 3     4   Thomas    1000      10  2019-08-18
# 4     5     Jade    2000      10  2021-02-10
# 5     6    Smith    1000      10  2016-12-01
# 6     7   Robert    3000      20  2023-06-25
# 7     3     Nick    1000      30  2015-09-15
# 8     9    Naman    4000      30  2020-01-20
# 9     1    Vikas    1000      30  2017-10-03
# 10   11   Dennis   41000      30  2024-01-05
# 11   12    Karan    2200      20  2018-06-16
# 12   13   Simran    1500      10  2019-12-19
# 13   14     Amit    2000      30  2022-04-09
# 14   15     Neha    1700      20  2021-07-22
# 15   16    Rahul    1200      10  2016-03-28
# 16   17    Divya    3000      30  2015-11-11
# 17   18   Rakesh    1800      10  2020-09-04
# 18   19   Monica    2500      20  2023-08-07
# 19   20     John    2300      30  2018-10-29
# ...

# %%
from sqlalchemy import create_engine
mysql_conn = create_engine("mysql+pymysql://root:root@localhost:3306/sowjidb")
df.to_sql("employee",mysql_conn,index=False)
# Out:
# 4

# %%
# %pip install SQLAlchemy pymysql
# Out:
# ...
#   Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached greenlet-3.2.4-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# ...
# Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl (2.1 MB)
# Using cached pymysql-1.1.2-py3-none-any.whl (45 kB)
# Using cached greenlet-3.2.4-cp313-cp313-win_amd64.whl (299 kB)
# ...
#
#    ---------------------------------------- 0/3 [pymysql]
#    ---------------------------------------- 0/3 [pymysql]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
# ...

# %%
pd.read_sql("""select * from employee where Department in ('HR','IT')""",mysql_conn)
# Out:
#    Employee_ID    Name Department  Salary Joining_Date
# 0          101    Amit         HR   50000   2022-01-10
# 1          103  Chetan         IT   55000   2020-07-01

# %%
import cx_Oracle
oracle_conn = create_engine("oracle+cx_oracle://system:qazwsxEDC!23@localhost:1521/orclpdb.lan")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import cx_Oracle
#       2 oracle_conn = create_engine("oracle+cx_oracle://system:qazwsxEDC!23@localhost:1521/orclpdb.lan")
#
# ModuleNotFoundError: No module named 'cx_Oracle'
